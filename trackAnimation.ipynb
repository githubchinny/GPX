# %%
import trackanimation
from trackanimation.animation import AnimationTrack

input_directory = "/Users/mark/Documents/GitHub/python/gpx/cocking_edited.gpx"
cocking_trk = trackanimation.read_track(input_directory)
# sant_josep_trk = ibiza_trk.get_tracks_by_place('Sant Josep de sa Talaia', only_points=False)
# sant_josep_trk = sant_josep_trk.time_video_normalize(time=10, framerate=10)
cocking_trk = cocking_trk.time_video_normalize(time=10, framerate=10)


fig = AnimationTrack(df_points=cocking_trk, dpi=300, bg_map=True, map_transparency=0.5)
fig.make_video(output_file='filtering-by-place', framerate=10, linewidth=1.0)
# Out:
# ...
# Groups: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# Lowered zoom level to keep map size reasonable. (z = 17)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-11-5b8bb72ee773> in <module>
#       9
#      10
# ---> 11 fig = AnimationTrack(df_points=cocking_trk, dpi=300, bg_map=True, map_transparency=0.5)
#      12 fig.make_video(output_file='filtering-by-place', framerate=10, linewidth=1.0)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/trackanimation/animation.py in __init__(self, df_points, dpi, bg_map, aspect, map_transparency)
#      66             max_lng = trk_bounds.max_longitude
#      67             if bg_map:
# ---> 68                 self.map.append(smopy.Map((min_lat, min_lng, max_lat, max_lng)))
#      69                 self.axarr[i].imshow(self.map[i].img, aspect=aspect, alpha=map_transparency)
# ...
